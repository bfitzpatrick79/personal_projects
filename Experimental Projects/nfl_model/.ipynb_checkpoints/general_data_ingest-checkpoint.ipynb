# %%
import datetime as dt
import pandas as pd

# %%
# identifier for each team on pro-football-reference
teams = ['crd', # cardinals
         'atl', # falcons
         'rav', # ravens
         'buf', # bills
         'car', # panthers
         'chi', # bears
         'cin', # bengals
         'cle', # browns
         'dal', # cowboys
         'den', # denver
         'det', # lions
         'gnb', # packers
         'htx', # texans
         'clt', # colts
         'jax', # jaguars
         'kan', # chiefs
         'sdg', # chargers
         'ram', # rams
         'mia', # dolphins
         'min', # vikings
         'nwe', # patriots
         'nor', # saints
         'nyg', # giants
         'nyj', # jets
         'rai', # raiders
         'phi', # eagles
         'pit', # steelers
         'sfo', # 49ers
         'sea', # seahawks
         'tam', # buccs
         'oti', # titans
         'was' # football team
        ]
len(teams)
# Out:
# 32

# %%
# year range starts in 2002 because the houston texans didn't exist in a prior form, Causing it to kick an error later in the program.
current_season = dt.date.today().year
year_range = range(2002, current_season)
year_dict = {}

# %%
# %%time
# general data ingestion for every year, every team

for year in year_range:
    temp_dict={}
    for team in teams:
        url = f'https://www.pro-football-reference.com/teams/{team}/{year}.htm'
        data = pd.read_html(url, header=1)
        temp_dict[team] = data[1]
        temp_dict[team]['year'] = year
        temp_dict[team]['team'] = team
    print(f'{year} complete')
    print('-------------')
    year_dict[year] = temp_dict
# Out:
# 2002 complete
# -------------
# 2003 complete
# -------------
# 2004 complete
# -------------
# 2005 complete
# -------------
# 2006 complete
# -------------
# 2007 complete
# -------------
# 2008 complete
# -------------
# 2009 complete
# -------------
# 2010 complete
# -------------
# 2011 complete
# -------------
# 2012 complete
# -------------
# 2013 complete
# -------------
# 2014 complete
# -------------
# 2015 complete
# -------------
# 2016 complete
# -------------
# 2017 complete
# -------------
# 2018 complete
# -------------
# 2019 complete
# -------------
# Wall time: 4min 27s

# %%
# testing that I can access the dataframe
year_dict[2002]['rav']
# Out:
#     Week  Day          Date  Unnamed: 3 Unnamed: 4 Unnamed: 5  OT  Rec  \
# 0      1  Sun   September 8   1:04PM ET   boxscore          L NaN  0-1
# 1      2  Sun  September 15   1:02PM ET   boxscore          L NaN  0-2
# 2      3  NaN           NaN         NaN        NaN        NaN NaN  NaN
# 3      4  Mon  September 30   9:08PM ET   boxscore          W NaN  1-2
# 4      5  Sun     October 6   8:36PM ET   boxscore          W NaN  2-2
# 5      6  Sun    October 13  12:00PM ET   boxscore          L NaN  2-3
# 6      7  Sun    October 20   1:02PM ET   boxscore          W NaN  3-3
# 7      8  Sun    October 27   1:02PM ET   boxscore          L NaN  3-4
# 8      9  Sun    November 3   1:05PM ET   boxscore          L NaN  3-5
# 9     10  Sun   November 10   1:02PM ET   boxscore          W NaN  4-5
# 10    11  Sun   November 17   4:16PM ET   boxscore          L NaN  4-6
# 11    12  Sun   November 24   1:02PM ET   boxscore          W NaN  5-6
# 12    13  Sun    December 1   1:02PM ET   boxscore          W NaN  6-6
# 13    14  Sun    December 8   4:05PM ET   boxscore          L NaN  6-7
# 14    15  Sun   December 15   1:02PM ET   boxscore          W NaN  7-7
# 15    16  Sun   December 22   4:15PM ET   boxscore          L NaN  7-8
# 16    17  Sun   December 29   1:02PM ET   boxscore          L NaN  7-9
#
#    Unnamed: 8                   Opp  ...  1stD.1  TotYd.1  PassY.1  RushY.1  \
# 0           @     Carolina Panthers  ...    15.0    265.0    120.0    145.0
# 1         NaN  Tampa Bay Buccaneers  ...    17.0    279.0    205.0     74.0
# 2         NaN              Bye Week  ...     NaN      NaN      NaN      NaN
# 3         NaN        Denver Broncos  ...    30.0    403.0    306.0     97.0
# 4           @      Cleveland Browns  ...    21.0    433.0    371.0     62.0
# 5           @    Indianapolis Colts  ...    19.0    317.0    257.0     60.0
# 6         NaN  Jacksonville Jaguars  ...    22.0    397.0    224.0    173.0
# 7         NaN   Pittsburgh Steelers  ...    16.0    283.0    179.0    104.0
# 8           @       Atlanta Falcons  ...    14.0    241.0    115.0    126.0
# 9         NaN    Cincinnati Bengals  ...    20.0    372.0    249.0    123.0
# 10          @        Miami Dolphins  ...    17.0    337.0    221.0    116.0
# 11        NaN      Tennessee Titans  ...    19.0    402.0    281.0    121.0
# 12          @    Cincinnati Bengals  ...    25.0    381.0    303.0     78.0
# 13        NaN    New Orleans Saints  ...    22.0    359.0    209.0    150.0
# 14          @        Houston Texans  ...    15.0    277.0    182.0     95.0
# 15        NaN      Cleveland Browns  ...    19.0    256.0    193.0     63.0
# 16          @   Pittsburgh Steelers  ...    25.0    351.0    176.0    175.0
#
#     TO.1  Offense  Defense  Sp. Tms  year  team
# 0    NaN    -6.68     4.38    -4.20  2002   rav
# 1    NaN   -25.30     0.76    -4.50  2002   rav
# 2    NaN      NaN      NaN      NaN  2002   rav
# 3    3.0    -7.77     1.13    17.33  2002   rav
# 4    5.0     7.54     3.26    -2.80  2002   rav
# 5    1.0    -5.80     2.91     1.83  2002   rav
# 6    3.0    -7.13     9.84     2.43  2002   rav
# 7    1.0    -3.51    -2.20   -10.09  2002   rav
# 8    1.0    -5.43     7.57    -4.50  2002   rav
# 9    4.0     7.67     6.17    -1.94  2002   rav
# 10   NaN   -19.74    -3.15     3.89  2002   rav
# 11   4.0   -18.43    13.33     7.92  2002   rav
# 12   2.0    -0.81    -0.16    -0.20  2002   rav
# 13   2.0    -4.88    -6.90    -4.33  2002   rav
# 14   2.0     2.78     8.64    -7.15  2002   rav
# 15   1.0     3.33    -3.44    -0.81  2002   rav
# 16   2.0    11.82    -7.19    -5.17  2002   rav
#
# [17 rows x 27 columns]

# %%
# column cleaning dictionary
column_clean_dict =  {
     'Day': 'Day_Week',
     'Unnamed: 3':'Kickoff_Time',
     'Unnamed: 5': 'W/L',
     'Unnamed: 8' : 'Home/Away',
     'Tm' : 'Team_Score',
     'Opp.1' : 'Oppo_score',
     '1stD' : '1D_gained',
     'TotYd' : 'Team_Total_Yards',
     'PassY' : 'Team_Pass_Yards',
     'RushY' : 'Team_Rush_Yards',
     'TO' : 'team_turnover',
     '1stD.1' : '1D_allowed',
     'TotYd.1' : 'oppo_total_yards',
     'PassY.1' : 'oppo_pass_yards',
     'RushY.1' : 'oppo_rush_yards',
     'TO.1' : 'oppo_turnover',
     'Offense' : 'offense_expected_points',
     'Defense' : 'defense_expected_points',
     'Sp. Tms' : 'sp_expected_points'
    }

# dictionary for mapping month into form for datetime transformation
month_dict = {
    'September' : 9,
    'October' : 10,
    'November' : 11,
    'December' : 12,
    'January' : 1,
    'February': 2
}

# %%
# cleans and standardizes each dataframe, adds datetime column
for year in year_dict:
    for team in year_dict[year]:
        iter_df = year_dict[year][team] #for my sanity.
        
        iter_df.rename(column_clean_dict, inplace=True, axis=1) # renames columns
        iter_df.drop('Unnamed: 4', axis=1, inplace=True) # drops an unused column
        
        iter_df.drop(iter_df[iter_df['Week'] == 'Playoffs'].index, inplace=True, axis=0) # drops blank row separating playoffs from regular season
        iter_df.drop(iter_df[iter_df['Opp'] == 'Bye Week'].index, inplace=True, axis=0) # drops bye weeks, will replace in future.
        iter_df.drop(iter_df[iter_df['Date']== 'Playoffs'].index, inplace=True, axis=0) # some rows have playoff marker in date
        
        iter_df['Week'].fillna(value=0, inplace=True)
        iter_df['Week'] = iter_df['Week'].astype(str)
        iter_df['Week'].replace({'Wild Card': 18, 'Division': 19, 'Conf. Champ.': 20, 'SuperBowl': 21}, inplace=True) # replaces str in 'Week' with playoff jgames like extension of regular season
        iter_df['Week'] = iter_df['Week'].astype(int) # turns back to int
        
        
        iter_df['OT'].fillna(value= 0, inplace=True) # replaces NaNs in the overtime column with 0
        iter_df['OT'] = iter_df['OT'].astype(str)
        iter_df['OT'].replace({'OT': 1}, inplace=True) # replaces 'OT' with 1 to signal overtime happened
        
        iter_df['W/L'].replace({'W' : 1, 'L': 0, 'T': 2}, inplace=True) # sets wins, losses, ties to numbers
        
        iter_df['Home/Away'].fillna(value='HOME', inplace=True) # fills in 'HOME' for home game
        iter_df['Home/Away'].replace({'@': 'AWAY', 'N':'Neutral'}, inplace=True) # fills in 'AWAY' for away game
        
        
        
        iter_df['team_turnover'].fillna(value=0, inplace=True) # fills 0s in for NaNs
        iter_df['oppo_turnover'].fillna(value=0, inplace=True) # fills 0s in for Nans
        
        iter_df['Kickoff_Time'].fillna(value='0', inplace=True)
        kick_time = []
        kick_split = []
        for i in iter_df['Kickoff_Time']:
            kick_time.append(i)
        for i in kick_time:
            kick_split.append(i.split()[0])
        iter_df['Kickoff_Time'] = kick_split
            
        
        month_list = []
        month_split = []
        for i in iter_df['Date']:
            month_list.append(i)
        for i in month_list:
            month_split.append(i.split()[0])
        iter_df['Month'] = month_split
        iter_df['Month'].replace(month_dict, inplace=True)

        day_split = []
        for i in month_list:
            day_split.append(i.split()[1])
        iter_df['Day'] = day_split
        iter_df['Day'] = iter_df['Day'].astype(int)
        
        year_list = []
        month_list = []
        day_list = []
        datetime_list = []

        for i in iter_df['year']:
            year_list.append(i)
        for i in iter_df['Month']:
            month_list.append(i)
        for i in iter_df['Day']:
            day_list.append(i)

        counter = 0
        for i in iter_df['year']:
            datetime_list.append(dt.datetime(year_list[counter], month_list[counter], day_list[counter]))
            counter += 1
        iter_df['dt_date'] = datetime_list
        
year_dict[2006]['chi'].dtypes
# Out:
# C:\Users\fitzp\Anaconda3\lib\site-packages\pandas\core\ops\array_ops.py:253: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   res_values = method(rvalues)
# Week                                int32
# Day_Week                           object
# Date                               object
# Kickoff_Time                       object
# W/L                                 int64
# OT                                 object
# Rec                                object
# Home/Away                          object
# Opp                                object
# Team_Score                        float64
# Oppo_score                        float64
# 1D_gained                         float64
# Team_Total_Yards                  float64
# Team_Pass_Yards                   float64
# Team_Rush_Yards                   float64
# team_turnover                     float64
# 1D_allowed                        float64
# oppo_total_yards                  float64
# oppo_pass_yards                   float64
# oppo_rush_yards                   float64
# oppo_turnover                     float64
# offense_expected_points           float64
# defense_expected_points           float64
# sp_expected_points                float64
# year                                int64
# team                               object
# Month                               int64
# Day                                 int32
# dt_date                    datetime64[ns]
# dtype: object

# %%
year_dict[2006]['chi']
# Out:
#     Week Day_Week          Date Kickoff_Time  W/L OT   Rec Home/Away  \
# 0      1      Sun  September 10       4:15PM    1  0   1-0      AWAY
# 1      2      Sun  September 17       1:03PM    1  0   2-0      HOME
# 2      3      Sun  September 24       1:05PM    1  0   3-0      AWAY
# 3      4      Sun     October 1       8:21PM    1  0   4-0      HOME
# 4      5      Sun     October 8       1:03PM    1  0   5-0      HOME
# 5      6      Mon    October 16       8:42PM    1  0   6-0      AWAY
# 7      8      Sun    October 29       1:03PM    1  0   7-0      HOME
# 8      9      Sun    November 5       1:02PM    0  0   7-1      HOME
# 9     10      Sun   November 12       8:21PM    1  0   8-1      AWAY
# 10    11      Sun   November 19       1:04PM    1  0   9-1      AWAY
# 11    12      Sun   November 26       4:15PM    0  0   9-2      AWAY
# 12    13      Sun    December 3       1:03PM    1  0  10-2      HOME
# 13    14      Mon   December 11       8:30PM    1  0  11-2      AWAY
# 14    15      Sun   December 17       1:05PM    1  1  12-2      HOME
# 15    16      Sun   December 24       1:03PM    1  0  13-2      AWAY
# 16    17      Sun   December 31       8:15PM    0  0  13-3      HOME
# 18    19      Sun    January 14       1:06PM    1  1  14-3      HOME
# 19    20      Sun    January 21       3:06PM    1  0  15-3      HOME
# 20    21      Sun    February 4       6:27PM    0  0  15-4   Neutral
#
#                      Opp  Team_Score  ...  oppo_rush_yards  oppo_turnover  \
# 0      Green Bay Packers        26.0  ...            103.0            3.0
# 1          Detroit Lions        34.0  ...             46.0            3.0
# 2      Minnesota Vikings        19.0  ...             97.0            2.0
# 3       Seattle Seahawks        37.0  ...             77.0            2.0
# 4          Buffalo Bills        40.0  ...             58.0            5.0
# 5      Arizona Cardinals        24.0  ...             66.0            2.0
# 7    San Francisco 49ers        41.0  ...            127.0            5.0
# 8         Miami Dolphins        13.0  ...            161.0            2.0
# 9        New York Giants        38.0  ...            150.0            3.0
# 10         New York Jets        10.0  ...            108.0            2.0
# 11  New England Patriots        13.0  ...             85.0            5.0
# 12     Minnesota Vikings        23.0  ...            190.0            5.0
# 13        St. Louis Rams        42.0  ...            101.0            1.0
# 14  Tampa Bay Buccaneers        34.0  ...             57.0            2.0
# 15         Detroit Lions        26.0  ...             67.0            1.0
# 16     Green Bay Packers         7.0  ...             97.0            1.0
# 18      Seattle Seahawks        27.0  ...            127.0            1.0
# 19    New Orleans Saints        39.0  ...             56.0            4.0
# 20    Indianapolis Colts        17.0  ...            191.0            3.0
#
#     offense_expected_points  defense_expected_points  sp_expected_points  \
# 0                      0.02                    12.18               11.20
# 1                     12.53                    10.87                4.21
# 2                     -8.81                    11.64                1.04
# 3                     12.91                    20.11                0.75
# 4                      9.21                    24.13               -0.82
# 5                    -35.67                    26.00               10.37
# 7                     14.41                    12.76                7.68
# 8                    -24.19                     3.26                1.87
# 9                     -4.12                    13.39                5.95
# 10                    -3.45                    17.43               -0.70
# 11                    -1.12                     4.63               -6.79
# 12                   -20.34                    25.70                2.99
# 13                    19.17                   -15.50                8.28
# 14                     9.42                     8.71              -15.69
# 15                     4.27                    -2.25               -1.72
# 16                   -25.05                    -1.51                5.25
# 18                     0.52                     2.87               -0.69
# 19                     3.01                    11.45               11.06
# 20                   -23.57                     3.78               10.43
#
#     year  team  Month  Day    dt_date
# 0   2006   chi      9   10 2006-09-10
# 1   2006   chi      9   17 2006-09-17
# 2   2006   chi      9   24 2006-09-24
# 3   2006   chi     10    1 2006-10-01
# 4   2006   chi     10    8 2006-10-08
# 5   2006   chi     10   16 2006-10-16
# 7   2006   chi     10   29 2006-10-29
# 8   2006   chi     11    5 2006-11-05
# 9   2006   chi     11   12 2006-11-12
# 10  2006   chi     11   19 2006-11-19
# 11  2006   chi     11   26 2006-11-26
# 12  2006   chi     12    3 2006-12-03
# 13  2006   chi     12   11 2006-12-11
# 14  2006   chi     12   17 2006-12-17
# 15  2006   chi     12   24 2006-12-24
# 16  2006   chi     12   31 2006-12-31
# 18  2006   chi      1   14 2006-01-14
# 19  2006   chi      1   21 2006-01-21
# 20  2006   chi      2    4 2006-02-04
#
# [19 rows x 29 columns]

# %%
# exports each team's data as an individual sheet in case I want to come back and work with those on a focused level
for team in teams:
    full_team = pd.DataFrame()
    for year in year_dict:
        full_team = full_team.append(year_dict[year][team])
    full_team.to_excel(r'C:\Users\fitzp\Desktop\GitR\git_repos\personal_projects\Experimental Projects\nfl_model\data\{}.xlsx'.format(team), sheet_name = team)

# %%
# combines all data into a single frame
full_data = pd.DataFrame()
for year in year_dict:
    for team in teams:
        full_data = full_data.append(year_dict[year][team])
full_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9612 entries, 0 to 16
# Data columns (total 29 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Week                     9612 non-null   int32
#  1   Day_Week                 9612 non-null   object
#  2   Date                     9612 non-null   object
#  3   Kickoff_Time             9612 non-null   object
#  4   W/L                      9612 non-null   int64
#  5   OT                       9612 non-null   object
#  6   Rec                      9612 non-null   object
#  7   Home/Away                9612 non-null   object
#  8   Opp                      9612 non-null   object
#  9   Team_Score               9612 non-null   float64
#  10  Oppo_score               9612 non-null   float64
#  11  1D_gained                9612 non-null   float64
#  12  Team_Total_Yards         9612 non-null   float64
#  13  Team_Pass_Yards          9610 non-null   float64
#  14  Team_Rush_Yards          9612 non-null   float64
#  15  team_turnover            9612 non-null   float64
#  16  1D_allowed               9612 non-null   float64
#  17  oppo_total_yards         9612 non-null   float64
#  18  oppo_pass_yards          9610 non-null   float64
#  19  oppo_rush_yards          9612 non-null   float64
#  20  oppo_turnover            9612 non-null   float64
#  21  offense_expected_points  9612 non-null   float64
#  22  defense_expected_points  9612 non-null   float64
#  23  sp_expected_points       9612 non-null   float64
#  24  year                     9612 non-null   int64
#  25  team                     9612 non-null   object
#  26  Month                    9612 non-null   int64
#  27  Day                      9612 non-null   int32
#  28  dt_date                  9612 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(15), int32(2), int64(3), object(8)
# memory usage: 2.1+ MB

# %%
full_data.to_excel('full_data_set.xlsx', sheet_name = 'Full Data')

# %%
full_data[full_data['oppo_pass_yards'].isnull()]
# Out:
#     Week Day_Week         Date Kickoff_Time  W/L OT   Rec Home/Away  \
# 16    17      Sun  December 28       4:15PM    1  0  4-12      HOME
# 16    17      Sun    January 3       8:31PM    1  0   9-7      HOME
#
#                    Opp  Team_Score  ...  oppo_rush_yards  oppo_turnover  \
# 16     Oakland Raiders        21.0  ...            141.0            1.0
# 16  Cincinnati Bengals        37.0  ...             72.0            3.0
#
#     offense_expected_points  defense_expected_points  sp_expected_points  \
# 16                     1.64                    25.91              -16.75
# 16                    10.82                    33.61               -6.11
#
#     year  team  Month  Day    dt_date
# 16  2003   sdg     12   28 2003-12-28
# 16  2009   nyj      1    3 2009-01-03
#
# [2 rows x 29 columns]

# %%
full_data[full_data['Team_Pass_Yards'].isnull()]
# Out:
#     Week Day_Week         Date Kickoff_Time  W/L OT   Rec Home/Away  \
# 16    17      Sun  December 28       4:15PM    0  0  4-12      AWAY
# 16    17      Sun    January 3       8:31PM    0  0  10-6      AWAY
#
#                    Opp  Team_Score  ...  oppo_rush_yards  oppo_turnover  \
# 16  San Diego Chargers        14.0  ...            263.0            0.0
# 16       New York Jets         0.0  ...            257.0            0.0
#
#     offense_expected_points  defense_expected_points  sp_expected_points  \
# 16                   -25.91                    -1.64               16.75
# 16                   -33.61                   -10.82                6.11
#
#     year  team  Month  Day    dt_date
# 16  2003   rai     12   28 2003-12-28
# 16  2009   cin      1    3 2009-01-03
#
# [2 rows x 29 columns]
