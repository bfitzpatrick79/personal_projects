# %%
import pandas as pd
import tweepy

# Variables that contains the credentials to access Twitter API
ACCESS_TOKEN = '952325675255414784-kJX116G9ByBhk5PRQXWIbFpDebfpluS'
ACCESS_SECRET = '9lFRMuNebYqdPIvt4xPkrWZr1xaWEXHyYJn45UBWNtGa1'
CONSUMER_KEY = 'aLcSeGRJw7zAakGj4djpCZ2Br'
CONSUMER_SECRET = 'tiZcs3SE5oWTc7GyTPBCFGxb0ByBvKNornNNrbnY2YyNhL3cwf'


# Setup access to API
def connect_to_twitter_OAuth():
    auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
    auth.set_access_token(ACCESS_TOKEN, ACCESS_SECRET)

    api = tweepy.API(auth)
    return api


# Create API object
api = connect_to_twitter_OAuth()

# %%
# tweets from my stream
public_tweets = api.home_timeline()
for tweet in public_tweets:
    print(tweet.text)
# Out:
# In Israel, any connection to the explosions in #Beirut is denied. https://t.co/JTPJu9JFnW
# Susan Rice Highlights Past Virus Response Efforts As She Vies For VP Slot https://t.co/rmP2ywcgsx https://t.co/dq93xzXSq4
# RT @ragipsoylu: Beirut governor is literally crying while talking about the explosions, who likens them to Nagasaki and Hiroshima attacks…
# Online video showed a column of smoke rising from the port area from what appeared to be an initial explosion, foll… https://t.co/CBo7Xwwa1T
# @caitlinnowens @AtriumHealth @darakass @allonbloch .@khealthCEO @allonbloch on how to use telehealth to lower healt… https://t.co/kwY2kglyH6
# The U.S. military should focus on the development of non-kinetic systems that can disarm adversary satellites witho… https://t.co/VkTmNCJyWR
# Tomorrow at 3 PM, Sophocles' Antigone with @HellenicStudies and @wordsofchaos https://t.co/fF8m6UkmwX
# ...

# %%
# tweets from a specific user
sputnik_tweets = api.user_timeline('SputnikInt')
for tweet in sputnik_tweets:
    print(tweet.text)
# Out:
# #BREAKING | At least one person reportedly killed in a massive explosion in #Beirut https://t.co/nSU27FeYXu… https://t.co/SJufM5C2yO
# #India copying US measures to contain #China's growing influence, observers say (Op-ed) https://t.co/U6Fdd00bXX
# How Ellen DeGeneres became 2020’s big villain
#
# @TheEllenShow
#
# https://t.co/eZxM9qXF1a
# UPDATE: #Lebanon’s health minister calls on hospitals to immediately mobilise and save lives of injured people… https://t.co/yBnjFlFiNw
# UPDATE: Lebanese electricity supplier's office in #Beirut completely destroyed
#
# #SputnikUpdates
#
# https://t.co/TnBXe7q9uV
# UPDATE: More than 30 Red Cross teams are working on site
#
# #SputnikUpdates #Beirut
#
# https://t.co/TnBXe7q9uV
# Watch the moment of the powerful explosion that ripped through the Lebanese capital #Beirut https://t.co/HGy48fNVvN
# UPDATE: Several buildings were destroyed in the blast, there may be people under rubble, Red Crescent reports… https://t.co/Gpl10o1LeV
# ...

# %%
# fuction to extract data from tweet object
def extract_tweet_attributes(tweet_object):
    # create empty list
    tweet_list =[]
    # loop through tweet objects
    for tweet in tweet_object:
        tweet_id = tweet.id # unique integer identifier for tweet
        text = tweet.text # utf-8 text of tweet
        favorite_count = tweet.favorite_count
        retweet_count = tweet.retweet_count
        created_at = tweet.created_at # utc time tweet created
        source = tweet.source # utility used to post tweet
        reply_to_status = tweet.in_reply_to_status_id # if reply int of orginal tweet id
        reply_to_user = tweet.in_reply_to_screen_name # if reply original tweetes screenname
        retweets = tweet.retweet_count # number of times this tweet retweeted
        favorites = tweet.favorite_count # number of time this tweet liked
        # append attributes to list
        tweet_list.append({'tweet_id':tweet_id, 
                          'text':text, 
                          'favorite_count':favorite_count,
                          'retweet_count':retweet_count,
                          'created_at':created_at, 
                          'source':source, 
                          'reply_to_status':reply_to_status, 
                          'reply_to_user':reply_to_user,
                          'retweets':retweets,
                          'favorites':favorites})
    # create dataframe   
    df = pd.DataFrame(tweet_list, columns=['tweet_id',
                                           'text',
                                           'favorite_count',
                                           'retweet_count',
                                           'created_at',
                                           'source',
                                           'reply_to_status',
                                           'reply_to_user',
                                           'retweets',
                                           'favorites'])
    return df


df = extract_tweet_attributes(sputnik_tweets)

# %%
df.head()
# Out:
#               tweet_id                                               text  \
# 0  1290689747367624712  #BREAKING | At least one person reportedly kil...
# 1  1290688950063910913  #India copying US measures to contain #China's...
# 2  1290686433653489664  How Ellen DeGeneres became 2020’s big villain ...
# 3  1290685930353942537  UPDATE: #Lebanon’s health minister calls on ho...
# 4  1290685669149417473  UPDATE: Lebanese electricity supplier's office...
#
#    favorite_count  retweet_count          created_at     source  \
# 0               0              0 2020-08-04 16:43:10  TweetDeck
# 1               1              2 2020-08-04 16:40:00  TweetDeck
# 2               2              1 2020-08-04 16:30:00  TweetDeck
# 3               4              4 2020-08-04 16:28:00  TweetDeck
# 4               6             14 2020-08-04 16:26:57  TweetDeck
#
#    reply_to_status reply_to_user  retweets  favorites
# 0     1.290686e+18    SputnikInt         0          0
# ...
