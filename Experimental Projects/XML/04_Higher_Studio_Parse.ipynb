# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
import numpy as np
import pprint

# %%
cik = '0001786874'

# %%
# returns pandas dataframe with filing information by cik
def cik_pull(cik):
    endpoint = r"https://www.sec.gov/cgi-bin/browse-edgar"

    # define our parameters dictionary
    param_dict = {'action':'getcompany',
                  'CIK':cik,
                  'type':'',
                  'dateb':'',
                  'owner':'exclude',
                  'start':'',
                  'output':'atom',
                  'count':'100'}

    # request the url, and then parse the response.
    response = requests.get(url = endpoint, params = param_dict)
    soup = BeautifulSoup(response.content, 'lxml')

    entries = soup.find_all('entry')

    file_type_list = []
    file_date_list = []
    url_list = []
    acc_num_list = []

    for entry in entries:
        file_type_list.append(entry.find('filing-type').text)
        file_date_list.append(entry.find('filing-date').text)
        acc_num_list.append(entry.find('accession-number').text)
        url_list.append(entry.find('filing-href').text)
    

    filings_df = pd.DataFrame()
    filings_df['file_type'] = file_type_list
    filings_df['file_date'] = file_date_list
    filings_df['acc_num'] = acc_num_list
    filings_df['url'] = url_list


    #this is for simplicity dealing with urls
    temp_list = []
    for i in acc_num_list:
        temp_list.append(i.replace('-', ''))
    filings_df['acc_num_url'] = temp_list
    
    return filings_df

# %%
# returns dataframe of an individual filing as 1 row, and however many parsed fields as columns
def idv_document_parse(acc_num):
    root_url = 'https://www.sec.gov/Archives/edgar/data/'
    cik_num = cik
    acc_num_url = acc_num
    xml_end = 'primary_doc.xml'
    target_url = root_url + cik_num + '/' + acc_num_url + '/' + xml_end
    
    file = requests.get(target_url)
    file_data = BeautifulSoup(file.content, 'lxml')
    
    tag_list = []
    data_list = []
    for i in file_data.find_all():
        tag_list.append(i.name)
        data_list.append(i.string)
    file_df = pd.DataFrame(columns = tag_list)
    data_series = pd.Series(data_list, index = file_df.columns)
    file_df = file_df.append(data_series, ignore_index=True)
    return file_df

# %%
# given a cik, returns dictionary with key value pair of unique file type - dataframe of parsed documents of that type
def all_files_parse(cik):
    filings_df = cik_pull(cik)
    
    file_dict = {}
    for file in filings_df['file_type'].unique():
        target_df = pd.DataFrame()
        iter_df = filings_df[filings_df['file_type'] == f'{file}']
        print(iter_df['file_type'].iloc[0])
    
        for i in range(len(iter_df)):
            sub = idv_document_parse(str(iter_df['acc_num_url'].iloc[i]))
            sub = sub.loc[:, ~sub.columns.duplicated()]
            target_df = target_df.append(sub).fillna(np.nan)
        file_dict[f'{file}'] = target_df
    return file_dict

# %%
# All fiings for a given cik
file_df = cik_pull(cik)
file_df
# Out:
#    file_type   file_date               acc_num  \
# 0       1-SA  2020-11-24  0001829126-20-000176
# 1      253G2  2020-08-28  0001213900-20-024150
# 2      253G2  2020-08-25  0001213900-20-023574
# 3     QUALIF  2020-08-20  9999999994-20-000171
# 4    CORRESP  2020-08-18  0001213900-20-022712
# 5    CORRESP  2020-08-07  0001213900-20-020956
# 6      1-A/A  2020-08-07  0001213900-20-020951
# 7     UPLOAD  2020-08-03  0000000000-20-007078
# 8    CORRESP  2020-07-21  0001213900-20-018131
# 9      1-A/A  2020-07-21  0001213900-20-018128
# 10    UPLOAD  2020-07-16  0000000000-20-006482
# 11   CORRESP  2020-07-02  0001213900-20-016549
# 12     1-A/A  2020-07-02  0001213900-20-016546
# 13    UPLOAD  2020-06-16  0000000000-20-005353
# 14      C-AR  2020-05-29  0001665160-20-000674
# 15       1-A  2020-05-21  0001213900-20-013167
# 16       C-U  2020-04-06  0001665160-20-000297
# 17       C/A  2020-01-29  0001665160-20-000063
# 18         C  2019-10-30  0001665160-19-001078
#
#                                                   url         acc_num_url
# 0   https://www.sec.gov/Archives/edgar/data/178687...  000182912620000176
# 1   https://www.sec.gov/Archives/edgar/data/178687...  000121390020024150
# 2   https://www.sec.gov/Archives/edgar/data/178687...  000121390020023574
# 3   https://www.sec.gov/Archives/edgar/data/178687...  999999999420000171
# 4   https://www.sec.gov/Archives/edgar/data/178687...  000121390020022712
# 5   https://www.sec.gov/Archives/edgar/data/178687...  000121390020020956
# 6   https://www.sec.gov/Archives/edgar/data/178687...  000121390020020951
# 7   https://www.sec.gov/Archives/edgar/data/178687...  000000000020007078
# 8   https://www.sec.gov/Archives/edgar/data/178687...  000121390020018131
# 9   https://www.sec.gov/Archives/edgar/data/178687...  000121390020018128
# 10  https://www.sec.gov/Archives/edgar/data/178687...  000000000020006482
# 11  https://www.sec.gov/Archives/edgar/data/178687...  000121390020016549
# 12  https://www.sec.gov/Archives/edgar/data/178687...  000121390020016546
# 13  https://www.sec.gov/Archives/edgar/data/178687...  000000000020005353
# 14  https://www.sec.gov/Archives/edgar/data/178687...  000166516020000674
# 15  https://www.sec.gov/Archives/edgar/data/178687...  000121390020013167
# 16  https://www.sec.gov/Archives/edgar/data/178687...  000166516020000297
# 17  https://www.sec.gov/Archives/edgar/data/178687...  000166516020000063
# 18  https://www.sec.gov/Archives/edgar/data/178687...  000166516019001078

# %%
# this is parsing the C filing as an example. inputting acc_num without dashes will parse any document you request.
idv_document_parse(str(file_df['acc_num_url'].iloc[-1]))
# Out:
#    html  body edgarsubmission headerdata submissiontype filerinfo filer  \
# 0  None  None            None       None              C      None  None
#
#   filercredentials    filercik  filerccc  ... signatureinfo issuersignature  \
# 0             None  0001786874  XXXXXXXX  ...          None            None
#
#                         issuer issuersignature  \
# 0  Called Higher Studios, Inc.     Jason Brown
#
#                                          issuertitle signaturepersons  \
# 0  CEO, Principal Executive Officer and Director,...             None
#
#   signatureperson personsignature  \
# 0            None     Jason Brown
#
#                                          persontitle signaturedate
# 0  CEO, Principal Executive Officer and Director,...    10-29-2019
#
# [1 rows x 129 columns]

# %%
# This is the result if there is no XML file for that acc_num.
idv_document_parse(str(file_df['acc_num_url'].iloc[0]))
# Out:
#    html  body error       code                            message  \
# 0  None  None  None  NoSuchKey  The specified key does not exist.
#
#                                                  key         requestid  \
# 0  edgar/data/1786874/000182912620000176/primary_...  4B0DB6BA9BC23EFC
#
#                                               hostid
# 0  H849z2+LMGlRCJ1qNrp7pNuzeWF12xgz5UCHFQOWXoT4zm...

# %%
all_files = all_files_parse(cik)
all_files['1-A/A']
# Out:
# 1-SA
# 253G2
# QUALIF
# CORRESP
# 1-A/A
# UPLOAD
# C-AR
# 1-A
# C-U
# C/A
# C
#    html  body  edgarsubmission  headerdata submissiontype  filerinfo  \
# 0   NaN   NaN              NaN         NaN          1-A/A        NaN
# 0   NaN   NaN              NaN         NaN          1-A/A        NaN
# 0   NaN   NaN              NaN         NaN          1-A/A        NaN
#
#   livetestflag  filer  issuercredentials         cik  ...  \
# 0         LIVE    NaN                NaN  0001786874  ...
# 0         LIVE    NaN                NaN  0001786874  ...
# 0         LIVE    NaN                NaN  0001786874  ...
#
#   issuejuridicationsecuritiesoffering dealersjuridicationsecuritiesoffering  \
# 0                                  AL                                    AL
# 0                                  AL                                    AL
# 0                                  AL                                    AL
#
#    securitiesissued         securitiesissuername        securitiesissuertitle  \
# 0               NaN  Called Higher Studios, Inc.  Class A Voting Common Stock
# 0               NaN  Called Higher Studios, Inc.  Class A Voting Common Stock
# 0               NaN  Called Higher Studios, Inc.  Class A Voting Common Stock
#
#    securitiesissuedtotalamount securitiesprincipalholderamount  \
# 0                      1074993                               0
# 0                      1074993                               0
# 0                      1074993                               0
#
#   securitiesissuedaggregateamount unregisteredsecuritiesact  \
# 0  $1,006,248 at $1.00 per share.                       NaN
# 0  $1,006,248 at $1.00 per share.                       NaN
# 0  $1,006,248 at $1.00 per share.                       NaN
#
#    securitiesactexcemption
# 0  Regulation Crowdfunding
# 0  Regulation Crowdfunding
# 0  Regulation Crowdfunding
#
# [3 rows x 107 columns]

# %%
all_files['C/A']
# Out:
#    html  body  edgarsubmission  headerdata submissiontype  filerinfo  filer  \
# 0   NaN   NaN              NaN         NaN            C/A        NaN    NaN
#
#    filercredentials    filercik  filerccc  ...  \
# 0               NaN  0001786874  XXXXXXXX  ...
#
#   issuejurisdictionsecuritiesoffering signatureinfo  issuersignature  \
# 0                                  AL           NaN              NaN
#
#                         issuer  \
# 0  Called Higher Studios, Inc.
#
#                                          issuertitle signaturepersons  \
# 0  CEO, Principal Executive Officer and Director,...              NaN
#
#    signatureperson  personsignature  \
# 0              NaN      Jason Brown
#
#                                          persontitle signaturedate
# 0  CEO, Principal Executive Officer and Director,...    01-29-2020
#
# [1 rows x 79 columns]

# %%
# converts dictionary of dataframes to json-like object

import json
json_dict = {}

for i in all_files:
    iter_json = all_files[i].to_json(orient= 'split')
    json_dict[i] = iter_json

# %%
# serializes dictionary
with open("higher_studios.json", "w") as outfile:  
    json.dump(json_dict, outfile)
