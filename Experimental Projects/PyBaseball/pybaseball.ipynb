# %%
from pybaseball import schedule_and_record
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

# %%
CLE_data_2014 = schedule_and_record(2014, 'CLE')
CLE_data_2015 = schedule_and_record(2015, 'CLE')
CLE_data_2016 = schedule_and_record(2016, 'CLE')

# %%
CHC_data_2014 = schedule_and_record(2014, 'CHC')
CHC_data_2015 = schedule_and_record(2015, 'CHC')
CHC_data_2016 = schedule_and_record(2016, 'CHC')

# %%
CLE_data_2014
# Out:
#                      Date   Tm Home_Away  Opp W/L    R   RA  Inn    W-L  Rank  \
# 1          Monday, Mar 31  CLE         @  OAK   W  2.0  0.0  9.0    1-0   1.0
# 2    Wednesday, Apr 2 (1)  CLE         @  OAK   L  1.0  6.0  9.0    1-1   3.0
# 3    Wednesday, Apr 2 (2)  CLE         @  OAK   W  6.0  4.0  9.0    2-1   3.0
# 4           Friday, Apr 4  CLE      Home  MIN   W  7.0  2.0  9.0    3-1   2.0
# 5         Saturday, Apr 5  CLE      Home  MIN   L  3.0  7.0  9.0    3-2   2.0
# ..                    ...  ...       ...  ...  ..  ...  ...  ...    ...   ...
# 158       Tuesday, Sep 23  CLE      Home  KCR   L  1.0  7.0  9.0  82-76   3.0
# 159     Wednesday, Sep 24  CLE      Home  KCR   W  6.0  4.0  9.0  83-76   3.0
# 160        Friday, Sep 26  CLE      Home  TBR   W  1.0  0.0  9.0  84-76   3.0
# 161      Saturday, Sep 27  CLE      Home  TBR   L  0.0  2.0  9.0  84-77   3.0
# 162        Sunday, Sep 28  CLE      Home  TBR   W  7.0  2.0  9.0  85-77   3.0
#
# ...

# %%
CHC_data_2014
# Out:
#                   Date   Tm Home_Away  Opp   W/L    R   RA   Inn    W-L  Rank  \
# 1       Monday, Mar 31  CHC         @  PIT  L-wo  0.0  1.0  10.0    0-1   4.0
# 2     Wednesday, Apr 2  CHC         @  PIT  L-wo  3.0  4.0  16.0    0-2   5.0
# 3      Thursday, Apr 3  CHC         @  PIT     W  3.0  2.0   9.0    1-2   3.0
# 4        Friday, Apr 4  CHC      Home  PHI     L  2.0  7.0   9.0    1-3   4.0
# 5      Saturday, Apr 5  CHC      Home  PHI     L  0.0  2.0   9.0    1-4   4.0
# ..                 ...  ...       ...  ...   ...  ...  ...   ...    ...   ...
# 158    Tuesday, Sep 23  CHC      Home  STL  W-wo  4.0  3.0  10.0  70-88   5.0
# 159  Wednesday, Sep 24  CHC      Home  STL     W  3.0  1.0   9.0  71-88   5.0
# 160     Friday, Sep 26  CHC         @  MIL     W  6.0  4.0   9.0  72-88   5.0
# 161   Saturday, Sep 27  CHC         @  MIL     L  1.0  2.0   9.0  72-89   5.0
# 162     Sunday, Sep 28  CHC         @  MIL     W  5.0  2.0   9.0  73-89   5.0
#
# ...

# %%
# Out:
#    index pitch_type  game_date  release_speed  release_pos_x  release_pos_z  \
# 0    444         SL 2016-05-01           88.4        -2.9596         6.3878
# 1    455         SI 2016-05-01           97.9        -2.7073         6.4099
# 2    467         SI 2016-05-01           97.7        -2.5522         6.3051
# 3    479         SI 2016-05-01           92.8        -2.8154         6.3742
# 4    491         SI 2016-05-01           98.6        -2.9162         6.1210
#
#      player_name    batter   pitcher     events  ... home_score  away_score  \
# 0  Blake Treinen  545341.0  595014.0  field_out  ...        1.0         6.0
# 1  Blake Treinen  545341.0  595014.0        NaN  ...        1.0         6.0
# 2  Blake Treinen  545341.0  595014.0        NaN  ...        1.0         6.0
# 3  Blake Treinen  571431.0  595014.0     single  ...        1.0         6.0
# 4  Blake Treinen  571431.0  595014.0        NaN  ...        1.0         6.0
#
# ...

# %%
cubs_df = schedule_and_record(2016, 'CHC')
cleveland_df = schedule_and_record(2016, 'CLE')
