# %%
import pandas as pd
from pytrends.request import TrendReq
import matplotlib.pyplot as plt
pytrend = TrendReq()

# %%
pytrend.build_payload(kw_list=['Qanon'])

# %%
df = pytrend.interest_by_region()
df.head(100)
# Out:
#                           Qanon
# geoName
# Afghanistan                   0
# Albania                       0
# Algeria                       0
# American Samoa                0
# Andorra                       0
# ...                         ...
# Guyana                        0
# Haiti                         0
# Heard & McDonald Islands      0
# Honduras                      0
# Hong Kong                     0
#
# [100 rows x 1 columns]

# %%
df.reset_index().plot(x='geoName', y='Qanon', figsize=(120, 10), kind ='bar')

# %%
pytrend.trending_searches(pn='united_states')
# Out:
#                               0
# 0                        Lakers
# 1         Axios Trump interview
# 2                        Beirut
# 3                Dominion power
# 4                  Barack Obama
# 5                    Blackhawks
# 6                     Tom Brady
# 7                     Sam Panda
# 8                 Katie Ledecky
# 9                    Debby Ryan
# 10                Biden VP pick
# 11                     Penguins
# 12  Great American Outdoors Act
# 13                 Nikola stock
# 14                          XFL
# 15                    Dale Moss
# 16                Bobby Shmurda
# 17                     Pixel 4a
# 18               Jonathan Isaac
# 19               Spurs vs 76ers

# %%
keywords = pytrend.suggestions(keyword='QAnon')
df = pd.DataFrame(keywords)
df.drop(columns= 'mid')   # This column makes no sense
# Out:
#         title       type
# 0       QAnon      Topic
# 1  Qanon Omar  TV series

# %%
pytrend.build_payload(kw_list=['QAnon'])

# %%
related_queries = pytrend.related_queries()
related_queries.values()
# Out:
# dict_values([{'top':                  query  value
# 0        qanon twitter    100
# 1          qanon posts     54
# 2        qanon what is     35
# 3          trump qanon     30
# 4                trump     30
# 5           qanon news     26
# 6        youtube qanon     23
# 7            qanon pub     22
# 8     qanon conspiracy     20
# 9         qanon latest     14
# 10                anon     13
# 11        qanon reddit     13
# 12         qanon drops     12
# 13              q anon     11
# 14          qanon post      9
# 15         4chan qanon      9
# 16      qanon facebook      9
# 17        who is qanon      8
# 18       trump twitter      8
# 19               4chan      8
# 20   qanon coronavirus      8
# 21         qanon today      8
# 22       qanon deutsch      7
# 23        qanon theory      7
# 24  qanon news twitter      7, 'rising':                  query   value
# 0          qanon posts  711300
# 1        qanon what is  463700
# 2          trump qanon  404350
# ...

# %%
related_topic = pytrend.related_topics()
related_topic.values()
# Out:
# dict_values([{'rising':       value formattedValue                                            link  \
# 0   1330700       Breakout     /trends/explore?q=/m/0289n8t&date=today+5-y
# 1    933200       Breakout     /trends/explore?q=/m/0hn1vcg&date=today+5-y
# 2    394950       Breakout      /trends/explore?q=/m/0cqt90&date=today+5-y
# 3    254550       Breakout      /trends/explore?q=/m/099v5d&date=today+5-y
# 4    180550       Breakout      /trends/explore?q=/m/0b2334&date=today+5-y
# 5    172000       Breakout     /trends/explore?q=/m/0bx7cy_&date=today+5-y
# 6    122000       Breakout       /trends/explore?q=/m/07kk5&date=today+5-y
# 7    112200       Breakout      /trends/explore?q=/m/02szg2&date=today+5-y
# 8    106550       Breakout       /trends/explore?q=/m/02z_b&date=today+5-y
# 9    104600       Breakout    /trends/explore?q=/m/012bhzwr&date=today+5-y
# 10    99950       Breakout       /trends/explore?q=/m/01p7f&date=today+5-y
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-216293a79882> in <module>
# ----> 1 related_topic.plot(kind='bar')
#
# AttributeError: 'dict' object has no attribute 'plot'

# %%
df = pytrend.get_historical_interest(['QAnon'], year_start=2020, month_start=1, day_start=1, hour_start=0, year_end=2020, month_end=8, day_end=3, hour_end=0, cat=0, geo='', gprop='', sleep=60)
# Out:
# HTTPSConnectionPool(host='trends.google.com', port=443): Read timed out. (read timeout=5)
